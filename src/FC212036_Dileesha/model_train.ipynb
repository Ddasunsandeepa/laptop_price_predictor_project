# %%
X_train = pd.read_csv('../splits/X_train_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X_train = pd.read_csv('../splits/X_train_dataset.csv')
#
# NameError: name 'pd' is not defined
